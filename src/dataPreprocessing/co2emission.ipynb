# %%
import pandas as pd

# %%
data = pd.read_csv(".../database/CO2EmissionEstimates.csv", delimiter=',', encoding = "ISO-8859-1", skiprows=1)
data.head(20)
# Out:
#     Region/Country/Area Unnamed: 1  Year  \
# 0                     8    Albania  1975
# 1                     8    Albania  1985
# 2                     8    Albania  2005
# 3                     8    Albania  2010
# 4                     8    Albania  2015
# 5                     8    Albania  2018
# 6                     8    Albania  2019
# 7                     8    Albania  2020
# 8                     8    Albania  1975
# 9                     8    Albania  1985
# 10                    8    Albania  2005
# 11                    8    Albania  2010
# 12                    8    Albania  2015
# 13                    8    Albania  2018
# 14                    8    Albania  2019
# 15                    8    Albania  2020
# 16                   12    Algeria  1975
# 17                   12    Algeria  1985
# 18                   12    Algeria  2005
# 19                   12    Algeria  2010
#
#                                                Series   Value Footnotes  \
# ...

# %%
data = data.drop(columns=["Footnotes"])
data
# Out:
#       Region/Country/Area Unnamed: 1  Year  \
# 0                       8    Albania  1975
# 1                       8    Albania  1985
# 2                       8    Albania  2005
# 3                       8    Albania  2010
# 4                       8    Albania  2015
# ...                   ...        ...   ...
# 2259                  716   Zimbabwe  2010
# 2260                  716   Zimbabwe  2015
# 2261                  716   Zimbabwe  2018
# 2262                  716   Zimbabwe  2019
# 2263                  716   Zimbabwe  2020
#
#                                                  Series  Value  \
# 0     Emissions (thousand metric tons of carbon diox...  4,524
# 1     Emissions (thousand metric tons of carbon diox...  7,145
# 2     Emissions (thousand metric tons of carbon diox...  3,980
# 3     Emissions (thousand metric tons of carbon diox...  4,074
# 4     Emissions (thousand metric tons of carbon diox...  3,975
# ...

# %%
data.dtypes
# Out:
# Region/Country/Area     int64
# Unnamed: 1             object
# Year                    int64
# Series                 object
# Value                  object
# Source                 object
# dtype: object

# %%
data["Value"] = data.Value.replace({',': ''}, regex=True).astype(float)
data
# Out:
#       Region/Country/Area Unnamed: 1  Year  \
# 0                       8    Albania  1975
# 1                       8    Albania  1985
# 2                       8    Albania  2005
# 3                       8    Albania  2010
# 4                       8    Albania  2015
# ...                   ...        ...   ...
# 2259                  716   Zimbabwe  2010
# 2260                  716   Zimbabwe  2015
# 2261                  716   Zimbabwe  2018
# 2262                  716   Zimbabwe  2019
# 2263                  716   Zimbabwe  2020
#
#                                                  Series   Value  \
# 0     Emissions (thousand metric tons of carbon diox...  4524.0
# 1     Emissions (thousand metric tons of carbon diox...  7145.0
# 2     Emissions (thousand metric tons of carbon diox...  3980.0
# 3     Emissions (thousand metric tons of carbon diox...  4074.0
# 4     Emissions (thousand metric tons of carbon diox...  3975.0
# ...

# %%
data = data.rename(columns={"Region/Country/Area": "Area code", "Unnamed: 1": "Area"})
data
# Out:
#       Country code   Country  Year  \
# 0                8   Albania  1975
# 1                8   Albania  1985
# 2                8   Albania  2005
# 3                8   Albania  2010
# 4                8   Albania  2015
# ...            ...       ...   ...
# 2259           716  Zimbabwe  2010
# 2260           716  Zimbabwe  2015
# 2261           716  Zimbabwe  2018
# 2262           716  Zimbabwe  2019
# 2263           716  Zimbabwe  2020
#
#                                                  Series   Value  \
# 0     Emissions (thousand metric tons of carbon diox...  4524.0
# 1     Emissions (thousand metric tons of carbon diox...  7145.0
# 2     Emissions (thousand metric tons of carbon diox...  3980.0
# 3     Emissions (thousand metric tons of carbon diox...  4074.0
# 4     Emissions (thousand metric tons of carbon diox...  3975.0
# ...                                                 ...     ...
# 2259  Emissions per capita (metric tons of carbon di...     0.7
# ...

# %%
data.to_csv(".../database/fixed/CO2EmissionEstimates.csv", index=False)
