# %%
import pandas as pd

# %%
data = pd.read_csv("../database/ExpenditureHealth.csv", delimiter=',', encoding = "ISO-8859-1", skiprows=1)
data
# Out:
#       Region/Country/Area   Unnamed: 1  Year  \
# 0                       4  Afghanistan  2005
# 1                       4  Afghanistan  2010
# 2                       4  Afghanistan  2015
# 3                       4  Afghanistan  2018
# 4                       4  Afghanistan  2019
# ...                   ...          ...   ...
# 2257                  716     Zimbabwe  2010
# 2258                  716     Zimbabwe  2015
# 2259                  716     Zimbabwe  2018
# 2260                  716     Zimbabwe  2019
# 2261                  716     Zimbabwe  2020
#
#                                                  Series  Value  \
# 0                 Current health expenditure (% of GDP)    9.9
# 1                 Current health expenditure (% of GDP)    8.6
# 2                 Current health expenditure (% of GDP)   10.1
# 3                 Current health expenditure (% of GDP)   14.2
# 4                 Current health expenditure (% of GDP)   14.8
# ...

# %%
data = data.drop(columns=["Footnotes"])
data
# Out:
#       Region/Country/Area   Unnamed: 1  Year  \
# 0                       4  Afghanistan  2005
# 1                       4  Afghanistan  2010
# 2                       4  Afghanistan  2015
# 3                       4  Afghanistan  2018
# 4                       4  Afghanistan  2019
# ...                   ...          ...   ...
# 2257                  716     Zimbabwe  2010
# 2258                  716     Zimbabwe  2015
# 2259                  716     Zimbabwe  2018
# 2260                  716     Zimbabwe  2019
# 2261                  716     Zimbabwe  2020
#
#                                                  Series  Value  \
# 0                 Current health expenditure (% of GDP)    9.9
# 1                 Current health expenditure (% of GDP)    8.6
# 2                 Current health expenditure (% of GDP)   10.1
# 3                 Current health expenditure (% of GDP)   14.2
# 4                 Current health expenditure (% of GDP)   14.8
# ...

# %%
data.dtypes
# Out:
# Region/Country/Area      int64
# Unnamed: 1              object
# Year                     int64
# Series                  object
# Value                  float64
# Source                  object
# dtype: object

# %%
data = data.rename(columns={"Region/Country/Area": "Area code", "Unnamed: 1": "Area"})
data
# Out:
#       Area code         Area  Year  \
# 0             4  Afghanistan  2005
# 1             4  Afghanistan  2010
# 2             4  Afghanistan  2015
# 3             4  Afghanistan  2018
# 4             4  Afghanistan  2019
# ...         ...          ...   ...
# 2257        716     Zimbabwe  2010
# 2258        716     Zimbabwe  2015
# 2259        716     Zimbabwe  2018
# 2260        716     Zimbabwe  2019
# 2261        716     Zimbabwe  2020
#
#                                                  Series  Value  \
# 0                 Current health expenditure (% of GDP)    9.9
# 1                 Current health expenditure (% of GDP)    8.6
# 2                 Current health expenditure (% of GDP)   10.1
# 3                 Current health expenditure (% of GDP)   14.2
# 4                 Current health expenditure (% of GDP)   14.8
# ...                                                 ...    ...
# 2257  Domestic general government health expenditure...   15.2
# ...

# %%
data.to_csv("../database/fixed/ExpenditureHealth.csv", index=False)
