# %%
import pandas as pd

# %%
data = pd.read_csv("../database/ImportsExports.csv", delimiter=',', encoding = "ISO-8859-1", skiprows=1)
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1995
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2020
# ...                   ...                            ...   ...
# 5048                  716                       Zimbabwe  2010
# 5049                  716                       Zimbabwe  2015
# 5050                  716                       Zimbabwe  2020
# 5051                  716                       Zimbabwe  2021
# 5052                  716                       Zimbabwe  2022
#
#                                                 Series System of trade  \
# 0                 Imports CIF (millions of US dollars)             NaN
# ...

# %%
data["System of trade"].unique()
# Out:
# array([nan, 'G', 'S'], dtype=object)

# %%
data = data.drop(columns=["Footnotes", "System of trade footnote"])
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1995
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2020
# ...                   ...                            ...   ...
# 5048                  716                       Zimbabwe  2010
# 5049                  716                       Zimbabwe  2015
# 5050                  716                       Zimbabwe  2020
# 5051                  716                       Zimbabwe  2021
# 5052                  716                       Zimbabwe  2022
#
#                                                 Series System of trade  \
# 0                 Imports CIF (millions of US dollars)             NaN
# ...

# %%
data.dtypes
# Out:
# Region/Country/Area     int64
# Unnamed: 1             object
# Year                    int64
# Series                 object
# System of trade        object
# Value                  object
# Source                 object
# dtype: object

# %%
data["Value"] = data.Value.replace({',': ''}, regex=True).astype(int)
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1995
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2020
# ...                   ...                            ...   ...
# 5048                  716                       Zimbabwe  2010
# 5049                  716                       Zimbabwe  2015
# 5050                  716                       Zimbabwe  2020
# 5051                  716                       Zimbabwe  2021
# 5052                  716                       Zimbabwe  2022
#
#                                                 Series System of trade  \
# 0                 Imports CIF (millions of US dollars)             NaN
# ...

# %%
data = data.rename(columns={"Region/Country/Area": "Area code", "Unnamed: 1": "Area"})
data
# Out:
#       Area code                           Area  Year  \
# 0             1  Total, all countries or areas  1995
# 1             1  Total, all countries or areas  2005
# 2             1  Total, all countries or areas  2010
# 3             1  Total, all countries or areas  2015
# 4             1  Total, all countries or areas  2020
# ...         ...                            ...   ...
# 5048        716                       Zimbabwe  2010
# 5049        716                       Zimbabwe  2015
# 5050        716                       Zimbabwe  2020
# 5051        716                       Zimbabwe  2021
# 5052        716                       Zimbabwe  2022
#
#                                                 Series System of trade  \
# 0                 Imports CIF (millions of US dollars)             NaN
# 1                 Imports CIF (millions of US dollars)             NaN
# 2                 Imports CIF (millions of US dollars)             NaN
# ...

# %%
data.to_csv("../database/fixed/ImportsExports.csv", index=False)
