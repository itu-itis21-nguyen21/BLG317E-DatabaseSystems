# %%
import pandas as pd

# %%
data = pd.read_csv("../database/ThreatenedSpecies.csv", delimiter=',', encoding = "ISO-8859-1", skiprows=1)
data
# Out:
#       Region/Country/Area   Unnamed: 1  Year  \
# 0                       4  Afghanistan  2004
# 1                       4  Afghanistan  2010
# 2                       4  Afghanistan  2015
# 3                       4  Afghanistan  2019
# 4                       4  Afghanistan  2020
# ...                   ...          ...   ...
# 6916                  716     Zimbabwe  2015
# 6917                  716     Zimbabwe  2019
# 6918                  716     Zimbabwe  2020
# 6919                  716     Zimbabwe  2021
# 6920                  716     Zimbabwe  2022
#
#                                         Series Value Footnotes  \
# 0     Threatened Species: Vertebrates (number)    31       NaN
# 1     Threatened Species: Vertebrates (number)    31       NaN
# 2     Threatened Species: Vertebrates (number)    31       NaN
# 3     Threatened Species: Vertebrates (number)    33       NaN
# 4     Threatened Species: Vertebrates (number)    33       NaN
# ...

# %%
data = data.drop(columns=["Footnotes"])
data
# Out:
#       Region/Country/Area   Unnamed: 1  Year  \
# 0                       4  Afghanistan  2004
# 1                       4  Afghanistan  2010
# 2                       4  Afghanistan  2015
# 3                       4  Afghanistan  2019
# 4                       4  Afghanistan  2020
# ...                   ...          ...   ...
# 6916                  716     Zimbabwe  2015
# 6917                  716     Zimbabwe  2019
# 6918                  716     Zimbabwe  2020
# 6919                  716     Zimbabwe  2021
# 6920                  716     Zimbabwe  2022
#
#                                         Series Value  \
# 0     Threatened Species: Vertebrates (number)    31
# 1     Threatened Species: Vertebrates (number)    31
# 2     Threatened Species: Vertebrates (number)    31
# 3     Threatened Species: Vertebrates (number)    33
# 4     Threatened Species: Vertebrates (number)    33
# ...                                        ...   ...
# ...

# %%
data.dtypes
# Out:
# Region/Country/Area     int64
# Unnamed: 1             object
# Year                    int64
# Series                 object
# Value                  object
# Source                 object
# dtype: object

# %%
data["Value"] = data.Value.replace({',': ''}, regex=True).astype(int)
data
# Out:
#       Region/Country/Area   Unnamed: 1  Year  \
# 0                       4  Afghanistan  2004
# 1                       4  Afghanistan  2010
# 2                       4  Afghanistan  2015
# 3                       4  Afghanistan  2019
# 4                       4  Afghanistan  2020
# ...                   ...          ...   ...
# 6916                  716     Zimbabwe  2015
# 6917                  716     Zimbabwe  2019
# 6918                  716     Zimbabwe  2020
# 6919                  716     Zimbabwe  2021
# 6920                  716     Zimbabwe  2022
#
#                                         Series  Value  \
# 0     Threatened Species: Vertebrates (number)     31
# 1     Threatened Species: Vertebrates (number)     31
# 2     Threatened Species: Vertebrates (number)     31
# 3     Threatened Species: Vertebrates (number)     33
# 4     Threatened Species: Vertebrates (number)     33
# ...                                        ...    ...
# ...

# %%
data = data.rename(columns={"Region/Country/Area": "Area code", "Unnamed: 1": "Area"})
data
# Out:
#       Area code         Area  Year                                    Series  \
# 0             4  Afghanistan  2004  Threatened Species: Vertebrates (number)
# 1             4  Afghanistan  2010  Threatened Species: Vertebrates (number)
# 2             4  Afghanistan  2015  Threatened Species: Vertebrates (number)
# 3             4  Afghanistan  2019  Threatened Species: Vertebrates (number)
# 4             4  Afghanistan  2020  Threatened Species: Vertebrates (number)
# ...         ...          ...   ...                                       ...
# 6916        716     Zimbabwe  2015        Threatened Species: Total (number)
# 6917        716     Zimbabwe  2019        Threatened Species: Total (number)
# 6918        716     Zimbabwe  2020        Threatened Species: Total (number)
# 6919        716     Zimbabwe  2021        Threatened Species: Total (number)
# 6920        716     Zimbabwe  2022        Threatened Species: Total (number)
#
# ...

# %%
data.to_csv("../database/fixed/ThreatenedSpecies.csv", index=False)
