# %%
import pandas as pd

# %%
data = pd.read_csv("../database/DevelopmentAid.csv", delimiter=',', encoding = "ISO-8859-1", skiprows=1)
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1985
# 1                       1  Total, all countries or areas  1995
# 2                       1  Total, all countries or areas  2005
# 3                       1  Total, all countries or areas  2010
# 4                       1  Total, all countries or areas  2015
# ...                   ...                            ...   ...
# 5106                  722                           SIDS  2010
# 5107                  722                           SIDS  2015
# 5108                  722                           SIDS  2019
# 5109                  722                           SIDS  2020
# 5110                  722                           SIDS  2021
#
#                                                  Series    Value  \
# 0     Net official development assistance received: ...   25,604
# 1     Net official development assistance received: ...   46,875
# 2     Net official development assistance received: ...   81,833
# 3     Net official development assistance received: ...   92,131
# 4     Net official development assistance received: ...  111,378
# ...                                                 ...      ...
# 5106  Net official development assistance received: ...      3.0
# 5107  Net official development assistance received: ...      1.7
# 5108  Net official development assistance received: ...      2.2
# 5109  Net official development assistance received: ...      3.7
# 5110  Net official development assistance received: ...      3.2
#
#                                               Footnotes  \
# 0     Including regional aid disbursements in additi...
# 1     Including regional aid disbursements in additi...
# 2     Including regional aid disbursements in additi...
# 3     Including regional aid disbursements in additi...
# 4     Including regional aid disbursements in additi...
# ...                                                 ...
# 5106                                                NaN
# 5107                                                NaN
# 5108                                                NaN
# 5109                                                NaN
# 5110                                                NaN
#
#                                                  Source
# 0     Organisation for Economic Co-operation and Dev...
# 1     Organisation for Economic Co-operation and Dev...
# 2     Organisation for Economic Co-operation and Dev...
# 3     Organisation for Economic Co-operation and Dev...
# 4     Organisation for Economic Co-operation and Dev...
# ...                                                 ...
# 5106  Organisation for Economic Co-operation and Dev...
# 5107  Organisation for Economic Co-operation and Dev...
# 5108  Organisation for Economic Co-operation and Dev...
# 5109  Organisation for Economic Co-operation and Dev...
# 5110  Organisation for Economic Co-operation and Dev...
#
# [5111 rows x 7 columns]

# %%
data = data.drop(columns=["Footnotes"])
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1985
# 1                       1  Total, all countries or areas  1995
# 2                       1  Total, all countries or areas  2005
# 3                       1  Total, all countries or areas  2010
# 4                       1  Total, all countries or areas  2015
# ...                   ...                            ...   ...
# 5106                  722                           SIDS  2010
# 5107                  722                           SIDS  2015
# 5108                  722                           SIDS  2019
# 5109                  722                           SIDS  2020
# 5110                  722                           SIDS  2021
#
#                                                  Series    Value  \
# 0     Net official development assistance received: ...   25,604
# 1     Net official development assistance received: ...   46,875
# 2     Net official development assistance received: ...   81,833
# 3     Net official development assistance received: ...   92,131
# 4     Net official development assistance received: ...  111,378
# ...                                                 ...      ...
# 5106  Net official development assistance received: ...      3.0
# 5107  Net official development assistance received: ...      1.7
# 5108  Net official development assistance received: ...      2.2
# 5109  Net official development assistance received: ...      3.7
# 5110  Net official development assistance received: ...      3.2
#
#                                                  Source
# 0     Organisation for Economic Co-operation and Dev...
# 1     Organisation for Economic Co-operation and Dev...
# 2     Organisation for Economic Co-operation and Dev...
# 3     Organisation for Economic Co-operation and Dev...
# 4     Organisation for Economic Co-operation and Dev...
# ...                                                 ...
# 5106  Organisation for Economic Co-operation and Dev...
# 5107  Organisation for Economic Co-operation and Dev...
# 5108  Organisation for Economic Co-operation and Dev...
# 5109  Organisation for Economic Co-operation and Dev...
# 5110  Organisation for Economic Co-operation and Dev...
#
# [5111 rows x 6 columns]

# %%
data.dtypes
# Out:
# Region/Country/Area     int64
# Unnamed: 1             object
# Year                    int64
# Series                 object
# Value                  object
# Source                 object
# dtype: object

# %%
data["Value"] = data.Value.replace({',': ''}, regex=True).astype(float)
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1985
# 1                       1  Total, all countries or areas  1995
# 2                       1  Total, all countries or areas  2005
# 3                       1  Total, all countries or areas  2010
# 4                       1  Total, all countries or areas  2015
# ...                   ...                            ...   ...
# 5106                  722                           SIDS  2010
# 5107                  722                           SIDS  2015
# 5108                  722                           SIDS  2019
# 5109                  722                           SIDS  2020
# 5110                  722                           SIDS  2021
#
#                                                  Series     Value  \
# 0     Net official development assistance received: ...   25604.0
# 1     Net official development assistance received: ...   46875.0
# 2     Net official development assistance received: ...   81833.0
# 3     Net official development assistance received: ...   92131.0
# 4     Net official development assistance received: ...  111378.0
# ...                                                 ...       ...
# 5106  Net official development assistance received: ...       3.0
# 5107  Net official development assistance received: ...       1.7
# 5108  Net official development assistance received: ...       2.2
# 5109  Net official development assistance received: ...       3.7
# 5110  Net official development assistance received: ...       3.2
#
#                                                  Source
# 0     Organisation for Economic Co-operation and Dev...
# 1     Organisation for Economic Co-operation and Dev...
# 2     Organisation for Economic Co-operation and Dev...
# 3     Organisation for Economic Co-operation and Dev...
# 4     Organisation for Economic Co-operation and Dev...
# ...                                                 ...
# 5106  Organisation for Economic Co-operation and Dev...
# 5107  Organisation for Economic Co-operation and Dev...
# 5108  Organisation for Economic Co-operation and Dev...
# 5109  Organisation for Economic Co-operation and Dev...
# 5110  Organisation for Economic Co-operation and Dev...
#
# [5111 rows x 6 columns]

# %%
data = data.rename(columns={"Region/Country/Area": "Area code", "Unnamed: 1": "Area"})
data
# Out:
#       Area code                           Area  Year  \
# 0             1  Total, all countries or areas  1985
# 1             1  Total, all countries or areas  1995
# 2             1  Total, all countries or areas  2005
# 3             1  Total, all countries or areas  2010
# 4             1  Total, all countries or areas  2015
# ...         ...                            ...   ...
# 5106        722                           SIDS  2010
# 5107        722                           SIDS  2015
# 5108        722                           SIDS  2019
# 5109        722                           SIDS  2020
# 5110        722                           SIDS  2021
#
#                                                  Series     Value  \
# 0     Net official development assistance received: ...   25604.0
# 1     Net official development assistance received: ...   46875.0
# 2     Net official development assistance received: ...   81833.0
# 3     Net official development assistance received: ...   92131.0
# 4     Net official development assistance received: ...  111378.0
# ...                                                 ...       ...
# 5106  Net official development assistance received: ...       3.0
# 5107  Net official development assistance received: ...       1.7
# 5108  Net official development assistance received: ...       2.2
# 5109  Net official development assistance received: ...       3.7
# 5110  Net official development assistance received: ...       3.2
#
#                                                  Source
# 0     Organisation for Economic Co-operation and Dev...
# 1     Organisation for Economic Co-operation and Dev...
# 2     Organisation for Economic Co-operation and Dev...
# 3     Organisation for Economic Co-operation and Dev...
# 4     Organisation for Economic Co-operation and Dev...
# ...                                                 ...
# 5106  Organisation for Economic Co-operation and Dev...
# 5107  Organisation for Economic Co-operation and Dev...
# 5108  Organisation for Economic Co-operation and Dev...
# 5109  Organisation for Economic Co-operation and Dev...
# 5110  Organisation for Economic Co-operation and Dev...
#
# [5111 rows x 6 columns]

# %%
data.to_csv("../database/fixed/DevelopmentAid.csv", index=False)
