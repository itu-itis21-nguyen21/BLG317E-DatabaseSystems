# %%
import pandas as pd

# %%
data = pd.read_csv("../database/InternetUsage.csv", delimiter=',', encoding = "ISO-8859-1", skiprows=1)
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2000
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2019
# ...                   ...                            ...   ...
# 1523                  199                           LDC§  2010
# 1524                  199                           LDC§  2015
# 1525                  199                           LDC§  2019
# 1526                  199                           LDC§  2020
# 1527                  199                           LDC§  2021
#
#                                             Series  Value  Footnotes  \
# 0     Percentage of individuals using the internet    5.3        NaN
# ...

# %%
data = data.drop(columns=["Footnotes"])
data
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2000
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2019
# ...                   ...                            ...   ...
# 1523                  199                           LDC§  2010
# 1524                  199                           LDC§  2015
# 1525                  199                           LDC§  2019
# 1526                  199                           LDC§  2020
# 1527                  199                           LDC§  2021
#
#                                             Series  Value  \
# 0     Percentage of individuals using the internet    5.3
# 1     Percentage of individuals using the internet   15.6
# ...

# %%
data.dtypes
# Out:
# Region/Country/Area      int64
# Unnamed: 1              object
# Year                     int64
# Series                  object
# Value                  float64
# Source                  object
# dtype: object

# %%
data = data.rename(columns={"Region/Country/Area": "Area code", "Unnamed: 1": "Area"})
data
# Out:
#       Area code                           Area  Year  \
# 0             1  Total, all countries or areas  2000
# 1             1  Total, all countries or areas  2005
# 2             1  Total, all countries or areas  2010
# 3             1  Total, all countries or areas  2015
# 4             1  Total, all countries or areas  2019
# ...         ...                            ...   ...
# 1523        199                           LDC§  2010
# 1524        199                           LDC§  2015
# 1525        199                           LDC§  2019
# 1526        199                           LDC§  2020
# 1527        199                           LDC§  2021
#
#                                             Series  Value  \
# 0     Percentage of individuals using the internet    5.3
# 1     Percentage of individuals using the internet   15.6
# 2     Percentage of individuals using the internet   28.5
# 3     Percentage of individuals using the internet   40.0
# ...

# %%
data.to_csv("../database/fixed/InternetUsage.csv", index=False)
